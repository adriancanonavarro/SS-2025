# %% [markdown]
# ## ICE Summer School : SN Cosmology
#  * Notebook developed by Mathew Smith (mat.smith@lancaster.ac.uk)

# %% [markdown]
# ## Part 1: Deriving Distances
#
#  * SN Cosmology is built on determining accurate distances into the early universe
#  * The latest data release from the Zwicky Transient Facility (ZTF-DR2) has recently been made available
#  * Today, we will download and exploit this dataset.
#  * We will use the SALT2 model to parameterise the light-curves and use these parameters to determine distances

# %% [markdown]
# Required libraries:
#  * numpy
#  * pandas
#  * scipy
#  * matplotlib
#  * sncosmo
#  * astropy
#  * scipy
#  * ztfcosmo

# %%
# !pip install ztfcosmo
import ztfcosmo
import numpy as np
import pandas as pd
from scipy import optimize as opt
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from astropy.table import Table
from astropy.cosmology import Planck18
import sncosmo
# Out:
# Collecting ztfcosmo
#   Downloading ztfcosmo-1.3.3-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from ztfcosmo) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from ztfcosmo) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from ztfcosmo) (3.10.0)
# Requirement already satisfied: astropy in /usr/local/lib/python3.11/dist-packages (from ztfcosmo) (7.1.0)
# Collecting sncosmo (from ztfcosmo)
#   Downloading sncosmo-2.12.1.tar.gz (241 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.4/241.4 kB 5.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting extinction (from ztfcosmo)
#   Downloading extinction-0.4.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting fastparquet (from ztfcosmo)
#   Downloading fastparquet-2024.11.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.11/dist-packages (from astropy->ztfcosmo) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.4.28.0.37.27 in /usr/local/lib/python3.11/dist-packages (from astropy->ztfcosmo) (0.2025.6.30.0.39.40)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from astropy->ztfcosmo) (6.0.2)
# Requirement already satisfied: packaging>=22.0.0 in /usr/local/lib/python3.11/dist-packages (from astropy->ztfcosmo) (24.2)
# Requirement already satisfied: cramjam>=2.3 in /usr/local/lib/python3.11/dist-packages (from fastparquet->ztfcosmo) (2.10.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from fastparquet->ztfcosmo) (2025.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->ztfcosmo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->ztfcosmo) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->ztfcosmo) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->ztfcosmo) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->ztfcosmo) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->ztfcosmo) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->ztfcosmo) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->ztfcosmo) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->ztfcosmo) (3.2.3)
# Requirement already satisfied: h5py>=3.11 in /usr/local/lib/python3.11/dist-packages (from sncosmo->ztfcosmo) (3.14.0)
# Collecting looseversion>=1.0.0 (from sncosmo->ztfcosmo)
#   Downloading looseversion-1.3.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from sncosmo->ztfcosmo) (1.15.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->ztfcosmo) (1.17.0)
# Downloading ztfcosmo-1.3.3-py3-none-any.whl (17 kB)
# Downloading extinction-0.4.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (600 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 600.1/600.1 kB 19.8 MB/s eta 0:00:00
# Downloading fastparquet-2024.11.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 36.5 MB/s eta 0:00:00
# Downloading looseversion-1.3.0-py2.py3-none-any.whl (8.2 kB)
# Building wheels for collected packages: sncosmo
#   Building wheel for sncosmo (pyproject.toml) ... done
#   Created wheel for sncosmo: filename=sncosmo-2.12.1-cp311-cp311-linux_x86_64.whl size=711653 sha256=0edf0dc49f8a73f1127bc4778dfade9dd23dacdaa26068c938c3980950efab05
#   Stored in directory: /root/.cache/pip/wheels/1f/e5/28/aab5c72a466334eefb8e8b3f36ac5d521f3c397c6fe133193a
# Successfully built sncosmo
# Installing collected packages: looseversion, extinction, sncosmo, fastparquet, ztfcosmo
# Successfully installed extinction-0.4.7 fastparquet-2024.11.0 looseversion-1.3.0 sncosmo-2.12.1 ztfcosmo-1.3.3

# %% [markdown]
# ### Some simple shortcuts for plotting and calculations

# %%
fac       = 2.5/np.log(10)
filts     = ['ztfg', 'ztfr', 'ztfi']
plot_cols = {'green':'#00A037', 'orange':'#FF7F2B', 'red':'#E0282F'}
filt_cols = [plot_cols['green'], plot_cols['red'], plot_cols['orange']]
errfloor  = {'ztfg':0.025, 'ztfr':0.035, 'ztfi':0.06}
#
colors    = {'blue':'#194D80', 'yellow':'#F8AD05', 'silver':'#ADADAD', 'green':'#566E3D', 'red':'#A22522'}

# %% [markdown]
# #### We can use ztfcosmo to download the latest ZTF-DR2 dataset

# %%
sample = ztfcosmo.get_data()
sample.tail(10)
# Out:
#               redshift  redshift_err source            t0        x0        x1  \
# ztfname
# ZUDS20dnrnc   0.130567      0.000026  z_gal  58895.740823  0.000181 -1.489423
# ZUDS20dofxx   0.270355      0.000100  z_gal  58879.720306  0.000056 -0.855391
# ZUDS20dpvgu   0.287793      0.000080  z_gal  58888.132311  0.000060  0.604321
# ZTF20aazhyrs  0.060106      0.000010  z_gal  58984.689347  0.000742 -0.204942
# ZTF18aaajrso  0.075372      0.000010  z_gal  58142.067608  0.000668  5.000000
# ZTF18acrxnme  0.078210      0.000014  z_gal  58459.559673  0.000720 -0.820927
# ZTF18aczeraq  0.058635      0.000011  z_gal  58483.107214  0.000913  0.985630
# ZTF20aciwcuz  0.061217      0.000013  z_gal  59190.000000  0.004948  5.000000
# ZTF19acdtmwh  0.069910      0.000015  z_gal  58774.273070  0.000468 -0.264331
# ZTF20aatvdwr  0.036318      0.000011  z_gal  58945.121621  0.005931  2.264104
#
#                      c    t0_err    x0_err    x1_err  ...   dec_host  \
# ztfname                                               ...
# ZUDS20dnrnc  -0.063092  0.183427  0.000007  0.208681  ...  50.622564
# ZUDS20dofxx  -0.057820  0.722392  0.000003  0.608162  ...  46.326521
# ZUDS20dpvgu  -0.134716  0.331027  0.000003  0.450367  ...  52.615135
# ZTF20aazhyrs  0.076614  0.330191  0.000028  0.245044  ...  -5.941555
# ZTF18aaajrso -0.160439  0.739395  0.000047  1.148856  ...  30.932137
# ZTF18acrxnme -0.125119  0.271434  0.000035  0.344767  ...  -0.533578
# ZTF18aczeraq  0.088372  0.243003  0.000037  0.287474  ...  46.608658
# ZTF20aciwcuz -0.352244  0.037735  0.000161  0.113433  ...  45.006347
# ZTF19acdtmwh  0.199896  0.231173  0.000026  0.363013  ...  24.022772
# ZTF20aatvdwr  0.136763  0.302343  0.000230  0.269013  ...  -5.123963
#
#               globalmass  globalmass_err  globalrestframe_gz  \
# ztfname
# ZUDS20dnrnc       11.246        0.105304            1.415697
# ZUDS20dofxx          NaN             NaN                 NaN
# ZUDS20dpvgu          NaN             NaN                 NaN
# ZTF20aazhyrs       9.631        0.101119            0.481697
# ZTF18aaajrso       9.693        0.103325            0.711697
# ZTF18acrxnme      10.620        0.111360            1.084697
# ZTF18aczeraq       9.818        0.106977            0.867697
# ZTF20aciwcuz      10.378        0.101607            0.834697
# ZTF19acdtmwh      10.728        0.104995            0.875697
# ZTF20aatvdwr       9.835        0.103846            0.650697
#
#               globalrestframe_gz_err     d_dlr  localmass  localmass_err  \
# ztfname
# ZUDS20dnrnc                 0.029155  0.125176     10.374          0.091
# ZUDS20dofxx                      NaN  0.385745        NaN            NaN
# ZUDS20dpvgu                      NaN  0.064314        NaN            NaN
# ZTF20aazhyrs                0.018385  0.433523      9.294          0.013
# ZTF18aaajrso                0.028653  1.214915      7.708          0.069
# ZTF18acrxnme                0.019849  0.331819      9.949          0.030
# ZTF18aczeraq                0.022023  0.632983      8.656          0.040
# ZTF20aciwcuz                0.019209  0.585036      8.630          0.034
# ZTF19acdtmwh                0.019209  0.155724      9.556          0.044
# ZTF20aatvdwr                0.020518  1.638835      7.652          0.085
#
#               localrestframe_gz  localrestframe_gz_err
# ztfname
# ZUDS20dnrnc            1.359697               0.028302
# ZUDS20dofxx                 NaN                    NaN
# ZUDS20dpvgu                 NaN                    NaN
# ZTF20aazhyrs           0.573697               0.017692
# ZTF18aaajrso          -0.101303               0.653242
# ZTF18acrxnme           1.093697               0.019105
# ZTF18aczeraq           0.826697               0.033615
# ZTF20aciwcuz           0.814697               0.055362
# ZTF19acdtmwh           1.153697               0.019209
# ZTF20aatvdwr           0.651697               0.178194
#
# [10 rows x 40 columns]

# %% [markdown]
# ## For each object, we can obtain the light-curve and spectrum

# %%
# Select an example object
ztfname           = 'ZTF18aaqfziz'
ztfname           = 'ZTF19acryaon'
ztfname           = 'ZTF20aayxldg'
# --- #
entry             = sample.loc[ztfname]
entry[['ra','dec','sn_type','redshift','t0','x0','x1','c','mwebv','globalmass']]
# Out:
# ra               224.76911
# dec              19.587287
# sn_type         snia-cosmo
# redshift          0.053826
# t0            58245.601679
# x0                0.000929
# x1               -1.077813
# c                 0.151953
# mwebv             0.033994
# globalmass          10.801
# Name: ZTF18aaqfziz, dtype: object

# %% [markdown]
# ### Download and visualise the spectra

# %%
all_spec              = ztfcosmo.get_spec_datafile()
ztfname_spec          = all_spec[all_spec.ztfname==ztfname]
spec                  = ztfcosmo.get_target_spectra(ztfname)
ztfname_spec
# Out:
#                                                fullpath  \
# 1169  /data/ztfsniadr2/spectra/ZTF18aaqfziz_20180512...
#
#                                basename       ztfname      date telescope  \
# 1169  ZTF18aaqfziz_20180512_NTT_0.ascii  ZTF18aaqfziz  20180512       NTT
#
#      version  phase_obs     phase
# 1169       0   4.398321  4.173669

# %%
fig, axs              = plt.subplots(ncols=1, nrows=len(ztfname_spec), figsize=(10,8), layout="constrained")
# ----------------------------------------------------------- #
for n in np.arange(0,len(ztfname_spec)):
    if len(ztfname_spec)>1:
        this_spec     = spec[n][1]
        ax            = axs[n]
    else:
        this_spec     = spec[1]
        ax            = axs
    if 'variance' in this_spec.columns:
        _                 = ax.errorbar(this_spec.lbda, this_spec.flux, yerr=np.sqrt(this_spec.variance), fmt='o', \
                                            c='darkgrey', mfc='w', zorder=1, label=f'{ztfname_spec.iloc[n].phase:0.2f} days from '+r'$t_{max}$')
    else:
        _                 = ax.plot(this_spec.lbda, this_spec.flux, c='darkgrey', zorder=1, \
                                           label=f'{ztfname_spec.iloc[n].phase:0.2f} days from '+r'$t_{max}$')
    _                 = ax.axvline(6150*(1+entry.redshift), lw=2, color='black', ls='--')

    _                 = ax.set_ylabel('normalised flux')
    legend_data       = ax.legend(loc='upper right', fancybox=True, framealpha=0.8, prop={'size': 14})

_                     = ax.set_xlabel('wavelength [$\AA$]')

# %% [markdown]
# ## Download and visualise the light-curve in flux and magnitude-space

# %%
lc                    = ztfcosmo.get_target_lightcurve(ztfname)
lc['zpsys']           = 'ab'
lc                    = lc[['mjd', 'filter', 'flux', 'flux_err', 'ZP', 'zpsys','mag','mag_err']]
# Define the limiting magnitude for an observation
lc['mag_lim']         = lc.apply(lambda row: -2.5*np.log10(5*row['flux_err'])+row['ZP'] if \
                                 row['flux']/row['flux_err']<5. else float("NAN"), axis=1)
time_range            = [-30, 100]
lc                    = lc[(lc.mjd>entry.t0+time_range[0]) & (lc.mjd<entry.t0+time_range[1])]
# ----------------------------------------------------------- #
fig, axs              = plt.subplots(ncols=1, nrows=2, figsize=(10,8), layout="constrained", sharex='col')
# ----------------------------------------------------------- #
# Flux-space
for n, filt in enumerate(filts):
    lc_band           = lc[(lc['filter']==filt) & (lc['flux']/lc['flux_err']>=5)]
    nd_band           = lc[(lc['filter']==filt) & (lc['flux']/lc['flux_err']<5)]
    if (len(lc_band)>0) | (len(nd_band)>0):
        _             = axs[0].errorbar(lc_band.mjd,lc_band.flux, yerr=lc_band.flux_err, fmt='o', \
                                     c=filt_cols[n], mfc='w', zorder=1, label=filt)
        _             = axs[0].scatter(nd_band.mjd,nd_band.flux, marker='v', c=filt_cols[n], s=20, zorder=1)
# --- #
legend_elements       = [Line2D([0], [0], marker='o', lw=4, color='w', label=f'{ztfname} @ z={entry.redshift:0.3f}')]
legend_info           = axs[0].legend(handles=legend_elements, loc='upper right', fancybox=True, framealpha=0.8, \
                                   handlelength=0, handletextpad=0, prop={'size': 14})
_                     = axs[0].set_ylim(0,np.min([lc.flux.max()*1.1,1.2e5]))
_                     = axs[0].set_xlim(lc.mjd.min()-1, lc.mjd.max()+1)
_                     = axs[0].set_xlabel('MJD [days]')
_                     = axs[0].set_ylabel('normalised flux (ZP=30)')
_                     = axs[0].get_xaxis().set_visible(False)
# ----------------------------------------------------------- #
# Magnitude-space
for n, filt in enumerate(filts):
    lc_band           = lc[(lc['filter']==filt) & (lc['flux']/lc['flux_err']>=5)]
    nd_band           = lc[(lc['filter']==filt) & (lc['flux']/lc['flux_err']<5)]
    if (len(lc_band)>0) | (len(nd_band)>0):
        _             = axs[1].errorbar(lc_band.mjd,lc_band.mag, yerr=lc_band['mag_err'], fmt='o', \
                                        c=filt_cols[n], mfc='w', zorder=1, label=filt)
        _             = axs[1].scatter(nd_band.mjd,nd_band.mag_lim, marker='v', c=filt_cols[n], s=20, zorder=1)
_                     = axs[1].set_ylim(21.5,lc.mag.min()*0.95)
_                     = axs[1].set_xlim(lc.mjd.min()-1, lc.mjd.max()+1)
_                     = axs[1].set_xlabel('MJD [days]')
_                     = axs[1].set_ylabel('magnitude (AB)')
legend_filt           = axs[1].legend(loc='upper right', fancybox=True, framealpha=0.8, prop={'size': 14})

# %% [markdown]
# ### Our light-curves need an additional uncertainty due to photometric calibration
#  * For each data point we increase the uncertainties by including a term corresponding to (2.5%, 3.5%, 6%) of the measured flux

# %%
# Apply the error floor
for filt in filts:
    e_floor                   = errfloor[filt]
    valid                     = lc['filter']==filt
    lc.loc[valid, 'flux_err'] = np.sqrt( (lc['flux_err'][valid])**2 + (lc['flux'][valid]*e_floor)**2 )
# Recalculate magnitudes
lc['mag']                     = lc.apply(lambda row: -2.5*np.log10(row['flux'])+row['ZP'] if \
                                         row['flux']/(np.sqrt(row['flux_err']**2+1e-10**2))>=5 else 99.0, axis=1)
lc['mag_err']                 = lc.apply(lambda row: row['mag_err'] if \
                                         row['flux']/(np.sqrt(row['flux_err']**2+1e-10**2))>=5 else 99.0, axis=1)
lc['mag_lim']                 = lc.apply(lambda row: -2.5*np.log10(5*row['flux_err'])+row['ZP'] if \
                                         row['flux']/row['flux_err']<5. else float("NAN"), axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-79-417611752.py in <cell line: 0>()
#       2 for filt in filts:
#       3     e_floor                   = errfloor[filt]
# ----> 4     valid                     = lc['filter']==filt
#       5     lc.loc[valid, 'flux_err'] = np.sqrt( (lc['flux_err'][valid])**2 + (lc['flux'][valid]*e_floor)**2 )
#       6 # Recalculate magnitudes
#
# /usr/local/lib/python3.11/dist-packages/astropy/table/table.py in __getitem__(self, item)
#    2091     def __getitem__(self, item):
#    2092         if isinstance(item, str):
# -> 2093             return self.columns[item]
#    2094         elif isinstance(item, (int, np.integer)):
#    2095             return self.Row(self, item)
#
# /usr/local/lib/python3.11/dist-packages/astropy/table/table.py in __getitem__(self, item)
#     262         """
#     263         if isinstance(item, str):
# --> 264             return OrderedDict.__getitem__(self, item)
#     265         elif isinstance(item, (int, np.integer)):
#     266             return list(self.values())[item]
#
# KeyError: 'filter'

# %% [markdown]
# ***
# ## Light-curve fitting

# %% [markdown]
# ### We can use the SALT2 model to determine the best-fit parameters for our object
#  * Using the SNCosmo library (https://sncosmo.readthedocs.io/en/stable/index.html)
#      * Load the SALT2 model and set some suitable bounds for each parameter
#           * It may be useful to use the results from the `sample` table as guidance)
#      * Reformat the light-curve to astropy.Table format
#      * Using the light-curve and redshift (found in the `sample` table), fit the SALT2 model to retrieve ($x_1$,$c$)
#      * Plot the corresponding model on top of the data
#  * Extension: repeat for different bounds / multiple objects / extend to the SNooPy template

# %%
# !pip install sncosmo
# !pip install iminuit

# Importa librerías necesarias
import sncosmo
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table
import ztfcosmo  # Asegúrate de que este paquete esté importado correctamente

# Configuración
fac       = 2.5/np.log(10)
filts     = ['ztfg', 'ztfr', 'ztfi']
plot_cols = {'green':'#00A037', 'orange':'#FF7F2B', 'red':'#E0282F'}
filt_cols = [plot_cols['green'], plot_cols['red'], plot_cols['orange']]
errfloor  = {'ztfg':0.025, 'ztfr':0.035, 'ztfi':0.06}
colors    = {'blue':'#194D80', 'yellow':'#F8AD05', 'silver':'#ADADAD', 'green':'#566E3D', 'red':'#A22522'}

# Obtiene el resumen de objetos
sample = ztfcosmo.get_data()
print(sample)

# Elige el nombre de un objeto específico (modifica a gusto)
ztfname = sample.iloc[0]['ztfname']  # o elige el que quieras de sample

print(f"Analizando objeto: {ztfname}")

# Obtiene el lightcurve de ese objeto
lc_data = ztfcosmo.get_target_lightcurve(ztfname)

# Convierte a astropy.Table
lc_table = Table.from_pandas(lc_data)

# Define el modelo SALT2
model = sncosmo.Model(source='salt2')

# Si sabes el redshift, lo fijas aquí, si no, lo puedes dejar libre en los bounds
redshift = sample[sample['ztfname'] == ztfname]['z_cmb'].values[0]
model.set(z=redshift)

# Define los límites para los parámetros
bounds = {'t0': (lc_table['mjd'].min()-10, lc_table['mjd'].max()+10),
          'x0': (1e-6, 1e-3),
          'x1': (-3.0, 3.0),
          'c': (-0.3, 0.3)}

# Realiza el ajuste
result, fitted_model = sncosmo.fit_lc(lc_table, model,
                                      ['t0', 'x0', 'x1', 'c'],
                                      bounds=bounds)

# Imprime los resultados
print("\nParámetros ajustados:")
print(f"t0: {result.parameters[1]:.3f}")
print(f"x0: {result.parameters[2]:.6e}")
print(f"x1: {result.parameters[3]:.3f}")
print(f"c: {result.parameters[4]:.3f}")

# Grafica los datos y el modelo ajustado
sncosmo.plot_lc(lc_table, model=fitted_model, errors=result.errors)
plt.show()
# Out:
# Requirement already satisfied: sncosmo in /usr/local/lib/python3.11/dist-packages (2.12.1)
# Requirement already satisfied: astropy>=5.0 in /usr/local/lib/python3.11/dist-packages (from sncosmo) (7.1.0)
# Requirement already satisfied: extinction>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from sncosmo) (0.4.7)
# Requirement already satisfied: h5py>=3.11 in /usr/local/lib/python3.11/dist-packages (from sncosmo) (3.14.0)
# Requirement already satisfied: looseversion>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from sncosmo) (1.3.0)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.11/dist-packages (from sncosmo) (2.0.2)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from sncosmo) (6.0.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from sncosmo) (1.15.3)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.11/dist-packages (from astropy>=5.0->sncosmo) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.4.28.0.37.27 in /usr/local/lib/python3.11/dist-packages (from astropy>=5.0->sncosmo) (0.2025.6.30.0.39.40)
# Requirement already satisfied: packaging>=22.0.0 in /usr/local/lib/python3.11/dist-packages (from astropy>=5.0->sncosmo) (24.2)
# Requirement already satisfied: iminuit in /usr/local/lib/python3.11/dist-packages (2.31.1)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.11/dist-packages (from iminuit) (2.0.2)
#               redshift  redshift_err  source            t0        x0  \
# ztfname
# ZTF17aadlxmv  0.062019      0.000013   z_gal  58878.085277  0.001126
# ZTF18aaadqua  0.078672      0.002807  z_snid  58130.778798  0.000845
# ZTF18aaanzph  0.063718      0.000016   z_gal  58138.014461  0.000275
# ZTF18aaapivw  0.026341      0.004328  z_snid  58152.873526  0.001008
# ZTF18aaaqexr  0.070258      0.000022   z_gal  58893.687923  0.000610
# ...                ...           ...     ...           ...       ...
# ZTF18acrxnme  0.078210      0.000014   z_gal  58459.559673  0.000720
# ZTF18aczeraq  0.058635      0.000011   z_gal  58483.107214  0.000913
# ZTF20aciwcuz  0.061217      0.000013   z_gal  59190.000000  0.004948
# ZTF19acdtmwh  0.069910      0.000015   z_gal  58774.273070  0.000468
# ZTF20aatvdwr  0.036318      0.000011   z_gal  58945.121621  0.005931
#
#                     x1         c     t0_err    x0_err    x1_err  ...  \
# ztfname                                                          ...
# ZTF17aadlxmv  0.459966  0.062074   0.219280  0.000037  0.138519  ...
# ZTF18aaadqua  4.999999 -0.392734  14.743977  0.000103  5.314307  ...
# ZTF18aaanzph -1.224903  0.567260   8.873835  0.000350  0.514599  ...
# ZTF18aaapivw -4.999998  0.660968   0.971755  0.000943  2.279241  ...
# ZTF18aaaqexr -1.437246  0.048229   0.170907  0.000021  0.225238  ...
# ...                ...       ...        ...       ...       ...  ...
# ZTF18acrxnme -0.820927 -0.125119   0.271434  0.000035  0.344767  ...
# ZTF18aczeraq  0.985630  0.088372   0.243003  0.000037  0.287474  ...
# ZTF20aciwcuz  5.000000 -0.352244   0.037735  0.000161  0.113433  ...
# ZTF19acdtmwh -0.264331  0.199896   0.231173  0.000026  0.363013  ...
# ZTF20aatvdwr  2.264104  0.136763   0.302343  0.000230  0.269013  ...
#
#                dec_host  globalmass  globalmass_err  globalrestframe_gz  \
# ztfname
# ZTF17aadlxmv  33.906468      10.424        0.116619            1.061697
# ZTF18aaadqua        NaN         NaN             NaN                 NaN
# ZTF18aaanzph  23.788548      10.996        0.123223            1.351697
# ZTF18aaapivw  27.141323       8.515        0.103325            0.591697
# ZTF18aaaqexr  15.566957      10.774        0.117661            1.211697
# ...                 ...         ...             ...                 ...
# ZTF18acrxnme  -0.533578      10.620        0.111360            1.084697
# ZTF18aczeraq  46.608658       9.818        0.106977            0.867697
# ZTF20aciwcuz  45.006347      10.378        0.101607            0.834697
# ZTF19acdtmwh  24.022772      10.728        0.104995            0.875697
# ZTF20aatvdwr  -5.123963       9.835        0.103846            0.650697
#
#               globalrestframe_gz_err     d_dlr  localmass  localmass_err  \
# ztfname
# ZTF17aadlxmv                0.018439  0.083759     10.001          0.025
# ZTF18aaadqua                     NaN       NaN      6.743          0.344
# ZTF18aaanzph                0.018439  1.698443      8.344          0.168
# ZTF18aaapivw                0.046861  2.969719      7.507          0.092
# ZTF18aaaqexr                0.018439  0.102694     10.727          0.065
# ...                              ...       ...        ...            ...
# ZTF18acrxnme                0.019849  0.331819      9.949          0.030
# ZTF18aczeraq                0.022023  0.632983      8.656          0.040
# ZTF20aciwcuz                0.019209  0.585036      8.630          0.034
# ZTF19acdtmwh                0.019209  0.155724      9.556          0.044
# ZTF20aatvdwr                0.020518  1.638835      7.652          0.085
#
#               localrestframe_gz  localrestframe_gz_err
# ztfname
# ZTF17aadlxmv           1.218697               0.017029
# ZTF18aaadqua           0.321697               1.289935
# ZTF18aaanzph           1.287697               0.500016
# ZTF18aaapivw           0.607697               0.336146
# ZTF18aaaqexr           1.313697               0.017692
# ...                         ...                    ...
# ZTF18acrxnme           1.093697               0.019105
# ZTF18aczeraq           0.826697               0.033615
# ZTF20aciwcuz           0.814697               0.055362
# ZTF19acdtmwh           1.153697               0.019209
# ZTF20aatvdwr           0.651697               0.178194
#
# [3628 rows x 40 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ztfname'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-86-3039889987.py in <cell line: 0>()
#      22
#      23 # Elige el nombre de un objeto específico (modifica a gusto)
# ---> 24 ztfname = sample.iloc[0]['ztfname']  # o elige el que quieras de sample
#      25
#      26 print(f"Analizando objeto: {ztfname}")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1235
#    1236         # Similar to Index.get_value, but we do not fall back to positional
# -> 1237         loc = self.index.get_loc(label)
#    1238
#    1239         if is_integer(loc):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'ztfname'

# %% [markdown]
# ***

# %% [markdown]
# ## Distance determination : photometric correlations
#  * For standard candles, then their distance could be derived from $\mu = m_B - M_{abs}$
#      * where $m_B = -2.5\times\log_{10}(x_0) + 10.653$
#      * and $\mu = 5\times\log_{10}\left(\frac{D_L}{10pc}\right) + 25$
# ***
#  * SNeIa are standardisable candles, so the above is modified to:
#      * $\mu = m_B - M_{abs} + \alpha\times x_1 - \beta\times c + \gamma(\text{mass})$
#      * where $(x1,c)$ were derived from our SALT2 fitting, ($\alpha,\beta$) are constants, and $\gamma$ is a step-wise function
#
#      * $\gamma(\text{globalmass}) = \left\{
#   \begin{array}{ c l }
#     -\gamma/2 & \quad \textrm{if } \text{globalmass} \geq 10 \\
#     \gamma/2  & \quad \textrm{otherwise}
#   \end{array}
# \right.$

# %% [markdown]
# ### Consider the unbiased, well-measured proportion of our dataset, by applying the following cuts:
#  * `lccoverage_flag==1` | `fitquality_flag==1` | `fitprob>1e-7`
#  *  `redshift>0.015` | `redshift<0.06`
#  *  `mass!=np.NaN`

# %%
best_sample    = sample[(sample.lccoverage_flag==1) & (sample.fitquality_flag==1) & (sample.fitprob>1e-7)]
vol_lim        = best_sample[(best_sample.redshift>0.015) & (best_sample.redshift<0.06)]
vol_lim        = vol_lim[~vol_lim.globalmass.isna()]
print(f'{len(vol_lim)} SNeIa comprise our sample')
# Out:
# 966 SNeIa comprise our sample

# %%
vol_lim.head(3)
# Out:
#               redshift  redshift_err  source            t0        x0  \
# ztfname
# ZTF18aabyhlc  0.029055      0.000015   z_gal  58180.621262  0.001247
# ZTF18aagrtxs  0.029741      0.000011   z_gal  58213.150268  0.005583
# ZTF18aagstdc  0.040367      0.003890  z_snid  58214.478445  0.004135
#
#                     x1         c    t0_err    x0_err    x1_err  ...  \
# ztfname                                                         ...
# ZTF18aabyhlc -2.747574  0.333068  0.504143  0.000122  0.091428  ...
# ZTF18aagrtxs -0.711100 -0.148609  0.041382  0.000170  0.037110  ...
# ZTF18aagstdc -0.047931 -0.097615  0.035815  0.000125  0.049832  ...
#
#                dec_host  globalmass  globalmass_err  globalrestframe_gz  \
# ztfname
# ZTF18aabyhlc  38.420393      10.003        0.120930            1.169697
# ZTF18aagrtxs  50.979166      10.583        0.154674            1.268697
# ZTF18aagstdc  42.088448       7.942        0.153154            1.082697
#
#               globalrestframe_gz_err     d_dlr  localmass  localmass_err  \
# ztfname
# ZTF18aabyhlc                0.019849  1.532268      7.405          0.263
# ZTF18aagrtxs                0.018439  0.391638      9.062          0.057
# ZTF18aagstdc                0.162111  0.146010      7.874          0.481
#
#               localrestframe_gz  localrestframe_gz_err
# ztfname
# ZTF18aabyhlc           0.732697               0.375373
# ZTF18aagrtxs           1.272697               0.021260
# ZTF18aagstdc           1.249697               1.128405
#
# [3 rows x 40 columns]

# %% [markdown]
# Define $m_B$ and $M_{abs}$

# %%
vol_lim.loc[:,'mB']      = -2.5*np.log10(vol_lim.x0) + 10.653
vol_lim.loc[:,'mB_err']  = fac*vol_lim.x0_err/vol_lim.x0
vol_lim.loc[:, 'M_abs']  = vol_lim.mB - Planck18.distmod(vol_lim.redshift).value

# %% [markdown]
# ### Determine ($\alpha$,$\beta$,$\gamma$) for our sample and measure distances
#  * Write two functions; one defining a linear relationship, the other defining a step-wise function
#  * Using a minimisation function (e.g. `opt.curve_fit`), visualise and determine the relationship between $M_{abs}$ and $c$ (aka $\beta$)
#  * Subtracting this correlation, determine the relationship between $M_{abs}$ and $x_1$ (aka $\alpha$)
#  * Subtracting this correlation, determine the relationship between $M_{abs}$ and $globalmass$ (aka $\gamma$)
#  * Visualise the results in three plots
# ***
#  * Use this information to determine the distance ($\mu$) to each event
#  * Plot a Hubble diagram, and the residuals for the ZTF-DR2 sample
# ***
#  * Extension: using the goodness of fit, determine how much dispersion (`$\sigma_{int}$`) is unexplained
#  * Extension: Is the distribution of $x_1$ gaussian? Is there a dependence on galaxy properties?
#  * Extension: repeat the above, only using a simultaneous fitting (MCMC) approach
#  * Extension: consider other environmental tracers ($localrestframe_gz$) and correlations between parameters

# %% [markdown]
# ### Done
# ***
